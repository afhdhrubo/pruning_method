# %%
# !git clone -b patched https://github.com/alamnahin/DSFP-Differential-Sensitivity-Fusion-Pruning.git
# %cd DSFP-Differential-Sensitivity-Fusion-Pruning
# !pip install -r requirements.txt
# !chmod +x setup.sh
# !chmod +x run.sh
# !./setup.sh
# !./run.sh

# Download zip after use !cd /kaggle/working/DSFP-Differential-Sensitivity-Fusion-Pruning && zip -r /kaggle/working/dsfp.zip . -x ".git" ".venv" ".pth" ".gitignore"
